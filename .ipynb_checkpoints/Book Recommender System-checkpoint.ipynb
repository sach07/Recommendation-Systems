# %%
import pandas as pd
import numpy as np
import scipy
from scipy.spatial.distance import hamming
from numpy.linalg import norm

# %%
file='BookRatings.csv'
#f=file.data.decode('utf8')
rating_data=pd.read_csv(file,sep=";",encoding = "ISO-8859-1")
rating_data.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
books_data=pd.read_csv('Books.csv',sep=";",error_bad_lines=False,usecols=[0,1,2],index_col=[0],encoding = "ISO-8859-1")
books_data.head()
# Out:
#                                                    Book-Title  \
# ISBN
# 0195153448                                Classical Mythology
# 0002005018                                       Clara Callan
# 0060973129                               Decision in Normandy
# 0374157065  Flu: The Story of the Great Influenza Pandemic...
# 0393045218                             The Mummies of Urumchi
#
#                      Book-Author
# ISBN
# 0195153448    Mark P. O. Morford
# 0002005018  Richard Bruce Wright
# 0060973129          Carlo D'Este
# 0374157065      Gina Bari Kolata
# 0393045218       E. J. W. Barber

# %%
def booksmetadata(isbn):
    return books_data[books_data.index==isbn]['Book-Title'],books_data[books_data.index==isbn]['Book-Author']

# %%
booksmetadata('034545104X')
# Out:
# (ISBN
#  034545104X    Flesh Tones: A Novel
#  Name: Book-Title, dtype: object, ISBN
#  034545104X    M. J. Rose
#  Name: Book-Author, dtype: object)

# %%
rating_data=rating_data[rating_data['ISBN'].isin(books_data.index)]

# %%
def favbooks(user,N):
    UserRating= rating_data[rating_data['User-ID']==user].sort_values('Book-Rating',ascending=False)[:N]
    #BookByUser=pd.merge(UserRating,books_data,on=UserRating['ISBN'])
    UserRating['Title']=UserRating['ISBN'].apply(booksmetadata)
    return UserRating

# %%
favbooks(204622,5)
# Out:
#         User-ID        ISBN  Book-Rating  \
# 844954   204622  0967560500           10
# 844934   204622  0671027360           10
# 844925   204622  0385504209           10
# 844957   204622  097173660X            9
# 844919   204622  0060935464            9
#
#                                                     Title
# 844954     ([Natural Hormonal Enhancement], [Rob Faigin])
# 844934               ([Angels &amp; Demons], [Dan Brown])
# 844925                 ([The Da Vinci Code], [Dan Brown])
# 844957  ([Life After School Explained], [Cap &amp; Com...
# 844919            ([To Kill a Mockingbird], [Harper Lee])

# %% [markdown]
# ## Problem Statement- Based on the above top 5 books read by this user an we recommend some other books

# %%
rating_data.shape
# Out:
# (1031174, 3)

# %%
rating_data['ISBN'].value_counts().shape
# Out:
# (270170,)

# %%
rating_data['User-ID'].value_counts().shape
# Out:
# (92106,)

# %%
UsersISBN=rating_data['ISBN'].value_counts()
rating_data=rating_data[rating_data['ISBN'].isin(UsersISBN[UsersISBN>10].index)]

# %%
ISBNperUsers=rating_data['User-ID'].value_counts()
rating_data=rating_data[rating_data['User-ID'].isin(ISBNperUsers[ISBNperUsers>10].index)]
rating_data
# Out:
#          User-ID        ISBN  Book-Rating
# 172       276847  0446364193            0
# 174       276847  3379015180            0
# 176       276847  3404148576            8
# 178       276847  3423071516           10
# 185       276847  3442413508           10
# 188       276847  3442437717            7
# 191       276847  3442444020            8
# 192       276847  3442446414           10
# 193       276847  3442448530            7
# 209       276847  3551551677           10
# 210       276847  3551551685           10
# 211       276847  3551551693           10
# 212       276847  3551551936           10
# 412       276925  002542730X           10
# 413       276925  0060520507            0
# 414       276925  0060930934            0
# 415       276925  0060951303            0
# 417       276925  0140154078            6
# 418       276925  0140327592            0
# 421       276925  0151010633            0
# 425       276925  0316666343            0
# 426       276925  0345391810            0
# 428       276925  0385504209            8
# 430       276925  0439284031            0
# 433       276925  0449221148            0
# 434       276925  0451527747            0
# 435       276925  0486282112            0
# 436       276925  0486424499            0
# 441       276925  0613329740            0
# 443       276925  067172939X            0
# ...          ...         ...          ...
# 1149695   276688  0446604666            0
# 1149696   276688  044661193X            7
# 1149698   276688  0451196813            0
# 1149699   276688  0515130117            0
# 1149705   276688  055308920X            0
# 1149706   276688  0553089218            0
# 1149707   276688  0553089226            0
# 1149708   276688  0553089234           10
# 1149710   276688  0553566040            6
# 1149711   276688  0553569155            0
# 1149712   276688  0553572512            7
# 1149713   276688  0553575090            7
# 1149714   276688  0553575104            6
# 1149720   276688  0679407111            0
# 1149721   276688  0679419810            0
# 1149722   276688  0679459596            0
# 1149723   276688  0679459618            0
# 1149724   276688  0679741836            0
# 1149725   276688  0679751521            0
# 1149727   276688  0684195569           10
# 1149728   276688  0684804484           10
# 1149730   276688  068484267X            0
# 1149735   276688  0688105548            0
# 1149736   276688  0688143687            0
# 1149737   276688  0688156134            8
# 1149738   276688  0743202694           10
# 1149742   276688  0836218655           10
# 1149743   276688  0836236688           10
# 1149744   276688  0892966548           10
# 1149745   276688  1551669315            6
#
# [379317 rows x 3 columns]

# %%
Rating_matrix=pd.pivot_table(rating_data,index='User-ID',columns='ISBN',values='Book-Rating')

# %%
User1=204622
User2=255489
User1Rating=Rating_matrix.transpose()[User1]
User2Rating=Rating_matrix.transpose()[User2]

# %%
User1Rating[User1Rating.notnull()]
# Out:
# ISBN
# 006016848X     0.0
# 0060935464     9.0
# 0140042598     0.0
# 0140178724     0.0
# 0142004278     4.0
# 0380732238     0.0
# 0385504209    10.0
# 0425109720     0.0
# 0425152898     0.0
# 0440136482     0.0
# 0440241162     0.0
# 0451191145     0.0
# 0451197127     0.0
# 0553096060     6.0
# 0671027360    10.0
# 0671027387     0.0
# 0671666258     8.0
# 0688174574     0.0
# 0743225708     0.0
# 076790592X     0.0
# 0785264280     0.0
# 0786868716     7.0
# 0802131867     0.0
# 0802132952     0.0
# 0971880107     0.0
# 1853260045     0.0
# 1853260126     0.0
# 1853260207     0.0
# 185326041X     0.0
# 1878424114     9.0
# Name: 204622, dtype: float64

# %%
hamming(User1Rating,User2Rating)
# Out:
# 0.9999352373550936

# %%
def computedistance(User1,User2):
    try:
        User1Rating=Rating_matrix.T[User1]
        User2Rating=Rating_matrix.T[User2]
        distance=hamming(User1,User2)
    except:
        distance=np.NaN
    return distance

# %%
computedistance(204622,10118)
# Out:
# 1.0

# %%
active_user=204622
all_users=pd.DataFrame(Rating_matrix.index)
all_users=all_users[all_users['User-ID']!=active_user]

# %%
all_users['Distance']=all_users['User-ID'].apply(lambda x: computedistance(active_user,x))

# %%
all_users.head()
# Out:
#    User-ID  Distance
# 0      243       1.0
# 1      254       1.0
# 2      383       1.0
# 3      388       1.0
# 4      424       1.0

# %%
K=10
KnearestUsers=all_users.sort_values('Distance',ascending=False)[:K]
KnearestUsers
# Out:
#       User-ID  Distance
# 0         243       1.0
# 4300   187256       1.0
# 4310   187624       1.0
# 4309   187613       1.0
# 4308   187606       1.0
# 4307   187598       1.0
# 4306   187574       1.0
# 4305   187520       1.0
# 4304   187517       1.0
# 4303   187425       1.0

# %%
def Knearest(activeuser,K):
    alluser=pd.DataFrame(Rating_matrix.index)
    alluser=alluser[alluser['User-ID']!=activeuser]
    alluser['distance']=alluser['User-ID'].apply(lambda x:computedistance(activeuser,x))
    kusers=alluser.sort_values('distance',ascending=False)['User-ID'][:K]
    return kusers

# %%
kusers=Knearest(204622,10)
kusers
# Out:
# 0          243
# 4300    187256
# 4310    187624
# 4309    187613
# 4308    187606
# 4307    187598
# 4306    187574
# 4305    187520
# 4304    187517
# 4303    187425
# Name: User-ID, dtype: int64

# %%
KnnRating=Rating_matrix[Rating_matrix.index.isin(kusers)]
KnnRating
# Out:
# ISBN     0002005018  0002251760  0002259834  0002558122  0006480764  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 187256          NaN         NaN         NaN         NaN         NaN
# 187425          NaN         NaN         NaN         NaN         NaN
# 187517          NaN         NaN         NaN         NaN         NaN
# 187520          NaN         NaN         NaN         NaN         NaN
# 187574          NaN         NaN         NaN         NaN         NaN
# 187598          NaN         NaN         NaN         NaN         NaN
# 187606          NaN         NaN         NaN         NaN         NaN
# 187613          NaN         NaN         NaN         NaN         NaN
# 187624          NaN         NaN         NaN         NaN         NaN
#
# ISBN     000648302X  0006485200  000649840X  000651202X  0006512062  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 187256          NaN         NaN         NaN         NaN         NaN
# 187425          NaN         NaN         NaN         NaN         NaN
# 187517          NaN         NaN         NaN         NaN         NaN
# 187520          NaN         NaN         NaN         NaN         NaN
# 187574          NaN         NaN         NaN         NaN         NaN
# 187598          NaN         NaN         NaN         NaN         NaN
# 187606          NaN         NaN         NaN         NaN         NaN
# 187613          NaN         NaN         NaN         NaN         NaN
# 187624          NaN         NaN         NaN         NaN         NaN
#
# ISBN        ...      8845906884  8845915611  8878188212  8885989403  \
# User-ID     ...
# 243         ...             NaN         NaN         NaN         NaN
# 187256      ...             NaN         NaN         NaN         NaN
# 187425      ...             NaN         NaN         NaN         NaN
# 187517      ...             NaN         NaN         NaN         NaN
# 187520      ...             NaN         NaN         NaN         NaN
# 187574      ...             NaN         NaN         NaN         NaN
# 187598      ...             NaN         NaN         NaN         NaN
# 187606      ...             NaN         NaN         NaN         NaN
# 187613      ...             NaN         NaN         NaN         NaN
# 187624      ...             NaN         NaN         NaN         NaN
#
# ISBN     9074336329  9074336469  950491036X  9681500830  9681500954  \
# User-ID
# 243             NaN         NaN         NaN         NaN         NaN
# 187256          NaN         NaN         NaN         NaN         NaN
# 187425          NaN         NaN         NaN         NaN         NaN
# 187517          NaN         NaN         NaN         NaN         NaN
# 187520          NaN         NaN         NaN         NaN         NaN
# 187574          NaN         NaN         NaN         NaN         NaN
# 187598          NaN         NaN         NaN         NaN         NaN
# 187606          NaN         NaN         NaN         NaN         NaN
# 187613          NaN         NaN         NaN         NaN         NaN
# 187624          NaN         NaN         NaN         NaN         NaN
#
# ISBN     9871138016
# User-ID
# 243             NaN
# 187256          NaN
# 187425          NaN
# 187517          NaN
# 187520          NaN
# 187574          NaN
# 187598          NaN
# 187606          NaN
# 187613          NaN
# 187624          NaN
#
# [10 rows x 15441 columns]

# %%
avgrating=KnnRating.apply(np.nanmean).dropna()
# Out:
# C:\Users\Sachin\Anaconda3\lib\site-packages\pandas\core\frame.py:4933: RuntimeWarning: Mean of empty slice
#   labels=labels)

# %%
avgrating
# Out:
# ISBN
# 0006550789     9.0
# 0007154615     0.0
# 0060011912     7.0
# 0060083948     5.0
# 0060096195     0.0
# 0060175400     0.0
# 0060176075     3.0
# 0060191929     0.0
# 006019491X     0.0
# 0060512377     7.0
# 0060557818     9.0
# 0060560754     7.0
# 0060808934    10.0
# 0060914653     0.0
# 0060915544    10.0
# 0060921145     8.5
# 0060924349     0.0
# 0060928336     9.0
# 006092988X     0.0
# 0060932759     7.0
# 0060938455     9.0
# 0060977493     7.0
# 0061000299     0.0
# 0061012882     0.0
# 006101351X     0.0
# 006101432X     0.0
# 0061020648     0.0
# 0061020680     0.0
# 0061031445     0.0
# 0061032476     5.0
#               ...
# 1551669234     9.0
# 1551669412     9.0
# 1551669625     0.0
# 1557732647     0.0
# 1558532854    10.0
# 155874262X     5.0
# 1558743669     0.0
# 1558745726     9.0
# 1558746161     0.0
# 1560252758     0.0
# 156402976X    10.0
# 1565075722     0.0
# 1565122968     8.0
# 156836010X     0.0
# 1579546463     0.0
# 1853260320     0.0
# 1853811262     0.0
# 1860492592     0.0
# 1860499627     9.0
# 202025462X    10.0
# 2070378411     8.0
# 2253049417    10.0
# 225313922X     9.0
# 2253139459    10.0
# 2253150711    10.0
# 2253152846     9.0
# 2253155039     0.0
# 2266022504     9.0
# 2266023039     9.0
# 2266104535     8.0
# Length: 730, dtype: float64

# %%
BooksAlreadyRead=Rating_matrix.T[active_user].dropna().index
BooksAlreadyRead
# Out:
# Index(['006016848X', '0060935464', '0140042598', '0140178724', '0142004278',
#        '0380732238', '0385504209', '0425109720', '0425152898', '0440136482',
#        '0440241162', '0451191145', '0451197127', '0553096060', '0671027360',
#        '0671027387', '0671666258', '0688174574', '0743225708', '076790592X',
#        '0785264280', '0786868716', '0802131867', '0802132952', '0971880107',
#        '1853260045', '1853260126', '1853260207', '185326041X', '1878424114'],
#       dtype='object', name='ISBN')

# %%
avgrating=avgrating[~avgrating.index.isin(BooksAlreadyRead)]

# %%
N=3
topISBNS=avgrating.sort_values(ascending=False).index[:N]

# %%
topISBNS
# Out:
# Index(['0439136350', '0394580567', '034541389X'], dtype='object', name='ISBN')

# %%
RecommendedBooks=pd.Series(topISBNS).apply(booksmetadata)
RecommendedBooks
# Out:
# 0    ([Harry Potter and the Prisoner of Azkaban (Bo...
# 1    ([It Was on Fire When I Lay Down on It], [Robe...
# 2            ([Flesh and Blood], [Jonathan Kellerman])
# Name: ISBN, dtype: object

# %%
def toprecommended(active_user,K):
    kusers=Knearest(active_user,K)
    KnnRating=Rating_matrix[Rating_matrix.index.isin(kusers)]
    avgrating=KnnRating.apply(np.nanmean).dropna()
    BooksAlreadyRead=Rating_matrix.T[active_user].dropna().index
    avgrating=avgrating[~avgrating.index.isin(BooksAlreadyRead)]
    topISBNS=avgrating.sort_values(ascending=False).index[:N]
    RecommendedBooks=pd.Series(topISBNS).apply(booksmetadata)
    #RecommendedBooks=RecommendedBooks.append(avgrating[:N])
    return RecommendedBooks

# %%
favbooks(204813,10)
# Out:
#         User-ID        ISBN  Book-Rating  \
# 845416   204813  0399149848           10
# 845406   204813  0385504209           10
# 845381   204813  0373218036           10
# 845358   204813  0142001805           10
# 845430   204813  0446527793           10
# 845415   204813  0399149392           10
# 845431   204813  0446531332            9
# 845433   204813  0446606243            9
# 845450   204813  0671027360            9
# 845432   204813  0446532452            9
#
#                                                     Title
# 845416                     ([Birthright], [Nora Roberts])
# 845406                 ([The Da Vinci Code], [Dan Brown])
# 845381         ([Truly, Madly Manhattan], [Nora Roberts])
# 845358      ([The Eyre Affair: A Novel], [Jasper Fforde])
# 845430                ([The Guardian], [Nicholas Sparks])
# 845415  ([Chesapeake Blue (Quinn Brothers (Hardcover))...
# 845431          ([Nights in Rodanthe], [Nicholas Sparks])
# 845433              ([The Tenth Justice], [Brad Meltzer])
# 845450               ([Angels &amp; Demons], [Dan Brown])
# 845432                 ([The Wedding], [Nicholas Sparks])

# %%
toprecommended(204813,10)
# Out:
# C:\Users\Sachin\Anaconda3\lib\site-packages\pandas\core\frame.py:4933: RuntimeWarning: Mean of empty slice
#   labels=labels)
# 0             ([Memoirs of a Geisha], [Arthur Golden])
# 1    ([The Autobiography of Foudini M. Cat], [Susan...
# 2                 ([The Color Purple], [Alice Walker])
# Name: ISBN, dtype: object

# %% [markdown]
# ## Recommending Products based on Latent Factor Model

# %%
rating_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 379317 entries, 172 to 1149745
# Data columns (total 3 columns):
# User-ID        379317 non-null int64
# ISBN           379317 non-null object
# Book-Rating    379317 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 11.6+ MB

# %%
from scipy.sparse import coo_matrix
rating_data['User-ID']=rating_data['User-ID'].astype("category")
rating_data['ISBN']=rating_data['ISBN'].astype("category")
R=coo_matrix((rating_data['Book-Rating'].astype(float),(rating_data['User-ID'].cat.codes.copy(),rating_data['ISBN'].cat.codes.copy())))

# %%
R.shape
# Out:
# (6457, 15441)

# %%
R.data[0]
# Out:
# 0.0

# %%
R.row[0]
# Out:
# 6414

# %%
R.col[0]
# Out:
# 6941

# %%
M,N=R.shape
K=3

# %%
P=np.random.rand(M,K)
Q=np.random.rand(K,N)

# %%
def error(R,P,Q,lamda=0.01):
    ratings=R.data
    col=R.col
    row=R.row
    e=0
    for ui in range(len(ratings)):
        rui=ratings[ui]
        u=row[ui]
        i=col[ui]
        if rui>0:
            e=e+pow(rui-np.dot(P[u,:],Q[:,i]),2)+\
            lamda*(pow(norm(P[u,:]),2)+pow(norm(Q[:,i]),2))
    return e

# %%
#error(R,P,Q)

# %%
#rmse=np.sqrt(error(R,P,Q)/len(R.data))

# %%
def SGD(R,K,lamda=0.02,gamma=0.001,steps=10):
    M,N=R.shape
    P=np.random.rand(M,K)
    Q=np.random.rand(K,N)
    rmse=np.sqrt(error(R,P,Q)/len(R.data))
    print('Initial RMSE'+str(rmse))
    for j in xrange(steps):
        for i in range(len(R.data)):
            rui=R.data[i]
            u=R.row[i]
            i=R.col[i]
            if rui>0:
                eui=rui-np.dot(P[u:],Q[:i])
                P[u,:]=P[u:]+gamma*2*(eui*Q[:,i]-lamda*P[u,:])
                Q[:,i]=Q[:,i]+gamma*2*(eui*P[u,:]-lamda*Q[:,i])
        rmse=np.sqrt(error(R,P,Q)/len(R.data))
        if rmse<0.5:
            break
        print("RMSE after optimization"+str(rmse))
        return P,Q

# %%
#,Q=SGD(R,K=2,gamma=0.001,lamda=0.01,steps=20)
